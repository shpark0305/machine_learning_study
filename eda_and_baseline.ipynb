# %%
import pandas as pd

# Load the training data
df = pd.read_csv('./data/train.csv')

# Inspect the data structure
print("--- HEAD ---")
print(df.head())
print("\n--- INFO ---")
print(df.info())
# Out:
# --- HEAD ---
#    t       x_3a  x_06      x_b1       x_7e  x_92      x_29  x_d4  x_4b  \
# 0  0  48.597037   1.0  0.140303  24.974895   0.0  6.686982   0.0   0.0
# 1  1  46.989782   1.0  0.957211  25.652101   0.0  0.000000   0.0   0.0
# 2  2  51.937353   1.0  2.345783  24.948010   0.0  1.102245   0.0   0.0
# 3  3  50.081326   1.0  2.877580  24.539312   0.0  0.000000   0.0   0.0
# 4  4  49.518314   1.0  4.905106  24.863596   0.0  2.372487   0.0   0.0
#
#        x_5c       x_f8
# 0  0.972448  22.025125
# 1  0.981402  22.030628
# 2  0.867604  22.053591
# 3  1.005693  22.032875
# 4  0.947125  22.032396
#
# --- INFO ---
# <class 'pandas.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   t       30000 non-null  int64
#  1   x_3a    30000 non-null  float64
#  2   x_06    30000 non-null  float64
#  3   x_b1    30000 non-null  float64
#  4   x_7e    30000 non-null  float64
# ...

# %%
# Summary statistics
print(df.describe())

# 1. Channel distribution (Histograms)
fig, axes = plt.subplots(5, 2, figsize=(12, 15))
axes = axes.flatten()
features = [col for col in df.columns if col != 't']

for i, col in enumerate(features):
    sns.histplot(df[col], ax=axes[i], kde=True, bins=30)
    axes[i].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.savefig('channel_distribution.png')
plt.close()

# 2. Time-series pattern (Line plots)
fig, axes = plt.subplots(5, 2, figsize=(12, 15))
axes = axes.flatten()
for i, col in enumerate(features):
    axes[i].plot(df['t'][:1000], df[col][:1000], label=col, color='blue', alpha=0.7) # plot first 1000 points for clarity
    axes[i].set_title(f'Time Series Pattern of {col} (First 1000 steps)')
    axes[i].set_xlabel('t')
plt.tight_layout()
plt.savefig('time_series_pattern.png')
plt.close()

# 3. Correlation between channels (Heatmap)
corr = df[features].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Channels')
plt.tight_layout()
plt.savefig('channel_correlation.png')
plt.close()
# Out:
#                   t          x_3a          x_06          x_b1          x_7e  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean   14999.500000     10.045609      0.199000     75.264274     60.491569
# std     8660.398374     19.935091      0.399255     32.188419     21.643489
# min        0.000000      0.000000      0.000000     -2.955392     22.868571
# 25%     7499.750000      0.000000      0.000000     50.663741     38.489218
# 50%    14999.500000      0.097202      0.000000     98.055424     69.286796
# 75%    22499.250000      0.460498      0.000000    100.029528     79.267336
# max    29999.000000     57.400447      1.000000    103.787606     83.933976
#
#                x_92          x_29          x_d4          x_4b          x_5c  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.202433    303.320547     11.951830      0.296667      1.147833
# ...

# %%
features = [col for col in df.columns if col != 't']

# 1. Channel distribution (Histograms)
fig, axes = plt.subplots(5, 2, figsize=(12, 15))
axes = axes.flatten()
for i, col in enumerate(features):
    sns.histplot(df[col], ax=axes[i], kde=True, bins=30)
    axes[i].set_title(f'Distribution of {col}')
plt.tight_layout()
plt.savefig('channel_distribution.png')
plt.close()

# 2. Time-series pattern (Line plots)
fig, axes = plt.subplots(5, 2, figsize=(12, 15))
axes = axes.flatten()
for i, col in enumerate(features):
    axes[i].plot(df['t'][:1000], df[col][:1000], label=col, color='blue', alpha=0.7)
    axes[i].set_title(f'Time Series Pattern of {col} (First 1000 steps)')
    axes[i].set_xlabel('t')
plt.tight_layout()
plt.savefig('time_series_pattern.png')
plt.close()

# 3. Correlation between channels (Heatmap)
corr = df[features].corr()
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, ax=ax)
ax.set_title('Correlation Matrix of Channels')
plt.tight_layout()
plt.savefig('channel_correlation.png')
plt.close()
print("Plots generated successfully!")
# Out:
# Plots generated successfully!
